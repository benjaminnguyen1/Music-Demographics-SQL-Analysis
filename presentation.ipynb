# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # SQL Project Presentation

# %% [markdown]
# # Job Posting
#
# Search : 'Data Analytics Music'
#
#
# Job: 'Content Data Scientist, Apple Media Products Data Science'

# %% [markdown]
# # Data Collection - API

# %%
api_key = 'BQApGqmUl6or22viraSHAbr9fmLpMd836YWYIgTj8RUADIKXZzDc1Avjj0VZp7dUrYQ3Rdl9moHnnNnQkKmm-WvhSiNhZyfyu4ilmV0Mf3PIb0mfhO-uEglgsz0-2QB4TmtNlifh7lDrnTeMQS4ewQJ-51mOpfd1nN2gKdDhtRyJouYU2ZoprbePLESqY3YPMbAcOAERkPKuIXxta9_1geXLFTD8Wb9r3wV5wQifvZNaggOr2x82KumEoIBTR0A0PQjrJb9C-qG6Lw'
Global_Top_50 = '/37i9dQZEVXbMDoHDwVN2tF'

music_api_url = 'https://api.spotify.com/v1/playlists' 

headers = {'Authorization': 'Bearer %s' % api_key}

music_request = requests.get(music_api_url + Global_Top_50, headers = headers)

# %%
music_request
# Out:
# <Response [200]>

# %%
music_request.text
# Out:
# '{\n  "collaborative" : false,\n  "description" : "Your daily update of the most played tracks right now.",\n  "external_urls" : {\n    "spotify" : "https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF"\n  },\n  "followers" : {\n    "href" : null,\n    "total" : 15193369\n  },\n  "href" : "https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF",\n  "id" : "37i9dQZEVXbMDoHDwVN2tF",\n  "images" : [ {\n    "height" : null,\n    "url" : "https://charts-images.scdn.co/REGIONAL_GLOBAL_DEFAULT.jpg",\n    "width" : null\n  } ],\n  "name" : "Global Top 50",\n  "owner" : {\n    "display_name" : "spotifycharts",\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/user/spotifycharts"\n    },\n    "href" : "https://api.spotify.com/v1/users/spotifycharts",\n    "id" : "spotifycharts",\n    "type" : "user",\n    "uri" : "spotify:user:spotifycharts"\n  },\n  "primary_color" : null,\n  "public" : false,\n  "snapshot_id" : "NjQwNjE5NjY1LDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDA
# ...

# %%
decoded_music_request_text = json.loads(music_request.text)

# %%
track_items = decoded_music_request_text['tracks']['items']
track_items
# Out:
# [{'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#       'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#       'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#       'name': 'The Weeknd',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
# ...

# %%
type(track_items)
# Out:
# list

# %%
top_50_data = {
    'track_name':[],
    'release_date':[],
    'artist_name':[],
    'artist_id':[]
}
for track in track_items:
    track_name = track['track']['name']
    top_50_data['track_name'].append(track_name)
    print(track_name)
     
    release_date = track['track']['album']['release_date']
    top_50_data['release_date'].append(release_date)
    print(release_date)
    
    artist = str(track['track']['album']['artists']).split(',')[3]
    artist_name = artist[10:-1]
    top_50_data['artist_name'].append(artist_name)    
    print(artist_name)
    
    artist = str(track['track']['album']['artists']).split(',')[2]
    artist_id = artist[8:-1]
    top_50_data['artist_id'].append(artist_id)
    print(artist_id)
    
    print('----------')
# Out:
# Blinding Lights
# 2020-03-20
# The Weeknd
# 1Xyo4u8uXC1ZmMpatF05PJ
# ----------
# Toosie Slide
# 2020-04-03
# Drake
# 3TVXtAsR1Inumwj472S9r4
# ----------
# Roses - Imanbek Remix
# 2019-10-09
# SAINt JHN
# 0H39MdGGX6dbnnQPt6NQkZ
# ----------
# Don't Start Now
# 2020-03-27
# Dua Lipa
# 6M2wZ9GZgrQXHCFfjv46we
# ----------
# death bed (coffee for your head) (feat. beabadoobee)
# 2020-02-08
# Powfu
# 6bmlMHgSheBauioMgKv2tn
# ----------
# Dance Monkey
# 2019-05-10
# Tones And I
# 2NjfBq1NflQcKSeiDooVjY
# ----------
# The Box
# 2019-12-06
# Roddy Ricch
# 757aE44tKEUQEqRuT6GnEB
# ----------
# Blueberry Faygo
# 2020-02-06
# Lil Mosey
# 5zctI4wO9XSKS8XwcnqEHk
# ----------
# Say So
# 2019-11-07
# Doja Cat
# 5cj0lLjcoR7YOSnhnX0Po5
# ----------
# ROCKSTAR (feat. Roddy Ricch)
# 2020-04-17
# DaBaby
# 4r63FhuTkUYltbVAg5TQnk
# ----------
# Break My Heart
# 2020-03-27
# Dua Lipa
# 6M2wZ9GZgrQXHCFfjv46we
# ----------
# Intentions (feat. Quavo)
# 2020-02-14
# Justin Bieber
# 1uNFoZAHBGtllmzznpCI3s
# ...

# %%
top_50_data
# Out:
# {'track_name': ['Blinding Lights',
#   'Toosie Slide',
#   'Roses - Imanbek Remix',
#   "Don't Start Now",
#   'death bed (coffee for your head) (feat. beabadoobee)',
#   'Dance Monkey',
#   'The Box',
#   'Blueberry Faygo',
#   'Say So',
#   'ROCKSTAR (feat. Roddy Ricch)',
#   'Break My Heart',
#   'Intentions (feat. Quavo)',
#   'Supalonely',
#   'Falling',
#   'Sunday Best',
#   'Safaera',
#   'Savage',
#   'Yo Perreo Sola',
#   'Tusa',
#   'ROXANNE',
#   'Someone You Loved',
#   'Boss Bitch',
#   'In Your Eyes',
#   'Circles',
#   'Physical',
#   '@ MEH',
#   'I’m Ready (with Demi Lovato)',
#   'WHATS POPPIN',
#   'Favorito',
#   'Adore You',
#   'Memories',
#   'Life Is Good (feat. Drake)',
#   'bad guy',
#   'Rojo',
#   'FIND MY WAY',
#   'ily (i love you baby) (feat. Emilee)',
#   'Señorita',
#   'Before You Go',
#   'Skechers',
#   'Godzilla (feat. Juice WRLD)',
#   'everything i wanted',
#   'If the World Was Ending - feat. Julia Michaels',
#   'Tattoo',
#   'La Difícil',
# ...

# %%
df = pd.DataFrame(top_50_data)

# %%
df.head()
# Out:
#                                           track_name release_date artist_name  \
# 0                                    Blinding Lights   2020-03-20  The Weeknd
# 1                                       Toosie Slide   2020-04-03       Drake
# 2                              Roses - Imanbek Remix   2019-10-09   SAINt JHN
# 3                                    Don't Start Now   2020-03-27    Dua Lipa
# 4  death bed (coffee for your head) (feat. beabad...   2020-02-08       Powfu
#
#                 artist_id
# 0  1Xyo4u8uXC1ZmMpatF05PJ
# 1  3TVXtAsR1Inumwj472S9r4
# 2  0H39MdGGX6dbnnQPt6NQkZ
# 3  6M2wZ9GZgrQXHCFfjv46we
# 4  6bmlMHgSheBauioMgKv2tn

# %%
df.to_csv('top_50_songs.csv', index = False)

# %%
engine = create_engine('mysql://USERNAME:PASSWORD@HOST/DATABASE')

# %%
df.to_sql('top_50_songs',engine, if_exists='replace')

# %%
for track in track_items:
    artist = str(track['track']['album']['artists']).split(',')[2]
    artist_id = artist[8:-1]
    print(artist_id +',')
# Out:
# 1Xyo4u8uXC1ZmMpatF05PJ,
# 3TVXtAsR1Inumwj472S9r4,
# 0H39MdGGX6dbnnQPt6NQkZ,
# 6M2wZ9GZgrQXHCFfjv46we,
# 6bmlMHgSheBauioMgKv2tn,
# 2NjfBq1NflQcKSeiDooVjY,
# 757aE44tKEUQEqRuT6GnEB,
# 5zctI4wO9XSKS8XwcnqEHk,
# 5cj0lLjcoR7YOSnhnX0Po5,
# 4r63FhuTkUYltbVAg5TQnk,
# 6M2wZ9GZgrQXHCFfjv46we,
# 1uNFoZAHBGtllmzznpCI3s,
# 0Cp8WN4V8Tu4QJQwCN5Md4,
# 7uaIm6Pw7xplS8Dy06V6pT,
# 4ETSs924pXMzjIeD6E9b4u,
# 4q3ewBCX7sLwd24euuV69X,
# 181bsRPaVXVlUKXrxwZfHK,
# 4q3ewBCX7sLwd24euuV69X,
# 790FomKkXshlbRYZFtlgla,
# 0vRvGUQVUjytro0xpb26bs,
# 4GNC7GD6oZMSxPGyXy4MNB,
# 5cj0lLjcoR7YOSnhnX0Po5,
# 1Xyo4u8uXC1ZmMpatF05PJ,
# 246dkjvS1zLTtiykXe5h60,
# 6M2wZ9GZgrQXHCFfjv46we,
# 699OTQXzgjhIYAHMy9RyPD,
# 2wY79sveU1sp5g7SokKOiI,
# 2LIk90788K0zvyj2JJVwkJ,
# 28gNT5KBp7IjEOQoevXf9N,
# 6KImCVD70vtIoJWnq6nGn3,
# 04gDigrS5kc9YWfZHwBETP,
# 1RyvyyTE3xzB2ZywiAwp0i,
# 6qqNVTkY8uBg9cP3Jd7DAH,
# 1vyhD5VmyZ7KMfW5gqLgo5,
# 4r63FhuTkUYltbVAg5TQnk,
# 1lmU3giNF3CSbkVSQmLpHQ,
# 7n2wHs1TKAczGzO7Dd2rGr,
# 4GNC7GD6oZMSxPGyXy4MNB,
# ...

# %%
import requests
import json
import pandas as pd
from sqlalchemy import create_engine

# %%
api_key = 'BQCH8V3FNcHS0OAwj96dBvI88rInm9N1DGu855BUQDYjBrwDdxXH6NbSBODQZRfovcWtD4nl6DuC1hbrZweaCJonTfjbxvqxSLBJ8cxrg-X4tSo2fx1-mpChv4kYVTXzQEYtKGsP5TKWVyJ16tAxDNXC-fjRSO-E7uvTllytOwaK5tXw4oicfitrtR1Vdmg8507MRCMXYPlkJUyA6zTGLR-6yi0gPJgbWHBn71BpWlyYRLcQUn_uJAWhHAnCYxQDClFjCZqo8vYqXQ'
artist_api_url = 'https://api.spotify.com/v1/artists' 

params = {'ids': '1Xyo4u8uXC1ZmMpatF05PJ,3TVXtAsR1Inumwj472S9r4,0H39MdGGX6dbnnQPt6NQkZ,6M2wZ9GZgrQXHCFfjv46we,6bmlMHgSheBauioMgKv2tn,2NjfBq1NflQcKSeiDooVjY,757aE44tKEUQEqRuT6GnEB,5zctI4wO9XSKS8XwcnqEHk,5cj0lLjcoR7YOSnhnX0Po5,4r63FhuTkUYltbVAg5TQnk,6M2wZ9GZgrQXHCFfjv46we,1uNFoZAHBGtllmzznpCI3s,0Cp8WN4V8Tu4QJQwCN5Md4,7uaIm6Pw7xplS8Dy06V6pT,4ETSs924pXMzjIeD6E9b4u,4q3ewBCX7sLwd24euuV69X,181bsRPaVXVlUKXrxwZfHK,4q3ewBCX7sLwd24euuV69X,790FomKkXshlbRYZFtlgla,0vRvGUQVUjytro0xpb26bs,4GNC7GD6oZMSxPGyXy4MNB,5cj0lLjcoR7YOSnhnX0Po5,1Xyo4u8uXC1ZmMpatF05PJ,246dkjvS1zLTtiykXe5h60,6M2wZ9GZgrQXHCFfjv46we,699OTQXzgjhIYAHMy9RyPD,2wY79sveU1sp5g7SokKOiI,2LIk90788K0zvyj2JJVwkJ,28gNT5KBp7IjEOQoevXf9N,6KImCVD70vtIoJWnq6nGn3,04gDigrS5kc9YWfZHwBETP,1RyvyyTE3xzB2ZywiAwp0i,6qqNVTkY8uBg9cP3Jd7DAH,1vyhD5VmyZ7KMfW5gqLgo5,4r63FhuTkUYltbVAg5TQnk,1lmU3giNF3CSbkVSQmLpHQ,7n2wHs1TKAczGzO7Dd2rGr,4GNC7GD6oZMSxPGyXy4MNB,3O5HD95HTEPgoPFOjAb7yV,7dGJo4pcD2V6oG8kP0tJRR,6qqNVTkY8uBg9cP3Jd7DAH,66W9LaWS0DPdL7Sz8iYGYe,1mcTU81TzQhprhouKaTkpq,4q3ewBCX7sLwd24euuV69X,1vyhD5VmyZ7KMfW5gqLgo5,4q3ewBCX7sLwd24euuV69X,4ofCBoyEiGSePFAG500xev,3YQKmKGau1PzlVlkL1iodx,0xRXCcSX89eobfrshSVdyu,4q3ewBCX7sLwd24euuV69X'}

headers = {'Authorization': 'Bearer %s' % api_key}

artist_request = requests.get(artist_api_url, params=params, headers = headers)

# %%
artist_request
# Out:
# <Response [200]>

# %%
artist_request.text
# Out:
# '{\n  "artists" : [ {\n    "external_urls" : {\n      "spotify" : "https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ"\n    },\n    "followers" : {\n      "href" : null,\n      "total" : 20035239\n    },\n    "genres" : [ "canadian contemporary r&b", "canadian pop", "pop" ],\n    "href" : "https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ",\n    "id" : "1Xyo4u8uXC1ZmMpatF05PJ",\n    "images" : [ {\n      "height" : 640,\n      "url" : "https://i.scdn.co/image/d9a875c37277c35b94c60c00d2cd256db098505d",\n      "width" : 640\n    }, {\n      "height" : 320,\n      "url" : "https://i.scdn.co/image/91c55730d3f156894d744d560afe441af3f5a228",\n      "width" : 320\n    }, {\n      "height" : 160,\n      "url" : "https://i.scdn.co/image/19393c56208fe6c312384879c11ff3da463f1304",\n      "width" : 160\n    } ],\n    "name" : "The Weeknd",\n    "popularity" : 98,\n    "type" : "artist",\n    "uri" : "spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ"\n  }, {\n    "external_urls" : {\n      "spot
# ...

# %%
decoded_artist_request_text = json.loads(artist_request.text)

# %%
artists=decoded_artist_request_text['artists']
artists
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#   'followers': {'href': None, 'total': 20035239},
#   'genres': ['canadian contemporary r&b', 'canadian pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#   'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/d9a875c37277c35b94c60c00d2cd256db098505d',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/91c55730d3f156894d744d560afe441af3f5a228',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/19393c56208fe6c312384879c11ff3da463f1304',
#     'width': 160}],
#   'name': 'The Weeknd',
#   'popularity': 98,
#   'type': 'artist',
#   'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#   'followers': {'href': None, 'total': 46038328},
# ...

# %%
artist_data = {
    'artist_id':[],
    'artist_name':[],
    'artist_genre':[],
    'artist_popularity':[]
}

for artist in artists:
    artist_id = artist['id']
    artist_data['artist_id'].append(artist_id)
    print(artist_id)
    
    artist_name = artist['name']
    artist_data['artist_name'].append(artist_name)
    print(artist_name)
    
    artist_genre = artist['genres']
    artist_genre_str = str(artist_genre).strip('[]')
    artist_genre_str = artist_genre_str.replace("'","").replace('"', '') 
    artist_data['artist_genre'].append(artist_genre_str)
    print(artist_genre_str)
    
    artist_popularity = artist['popularity']
    artist_data['artist_popularity'].append(artist_popularity)
    print(artist_popularity)
    
    print('----------------')
# Out:
# 1Xyo4u8uXC1ZmMpatF05PJ
# The Weeknd
# canadian contemporary r&b, canadian pop, pop
# 98
# ----------------
# 3TVXtAsR1Inumwj472S9r4
# Drake
# canadian hip hop, canadian pop, hip hop, pop rap, rap, toronto rap
# 99
# ----------------
# 0H39MdGGX6dbnnQPt6NQkZ
# SAINt JHN
# melodic rap, pop rap, rap, trap
# 88
# ----------------
# 6M2wZ9GZgrQXHCFfjv46we
# Dua Lipa
# dance pop, pop, uk pop
# 96
# ----------------
# 6bmlMHgSheBauioMgKv2tn
# Powfu
#
# 87
# ----------------
# 2NjfBq1NflQcKSeiDooVjY
# Tones And I
# australian pop
# 88
# ----------------
# 757aE44tKEUQEqRuT6GnEB
# Roddy Ricch
# melodic rap
# 94
# ----------------
# 5zctI4wO9XSKS8XwcnqEHk
# Lil Mosey
# melodic rap, rap conscient, trap, vapor trap
# 88
# ----------------
# 5cj0lLjcoR7YOSnhnX0Po5
# Doja Cat
# la indie, pop
# 91
# ----------------
# 4r63FhuTkUYltbVAg5TQnk
# DaBaby
# nc hip hop
# 94
# ----------------
# 6M2wZ9GZgrQXHCFfjv46we
# Dua Lipa
# dance pop, pop, uk pop
# 96
# ----------------
# 1uNFoZAHBGtllmzznpCI3s
# ...

# %%
artist_data
# Out:
# {'artist_id': ['1Xyo4u8uXC1ZmMpatF05PJ',
#   '3TVXtAsR1Inumwj472S9r4',
#   '0H39MdGGX6dbnnQPt6NQkZ',
#   '6M2wZ9GZgrQXHCFfjv46we',
#   '6bmlMHgSheBauioMgKv2tn',
#   '2NjfBq1NflQcKSeiDooVjY',
#   '757aE44tKEUQEqRuT6GnEB',
#   '5zctI4wO9XSKS8XwcnqEHk',
#   '5cj0lLjcoR7YOSnhnX0Po5',
#   '4r63FhuTkUYltbVAg5TQnk',
#   '6M2wZ9GZgrQXHCFfjv46we',
#   '1uNFoZAHBGtllmzznpCI3s',
#   '0Cp8WN4V8Tu4QJQwCN5Md4',
#   '7uaIm6Pw7xplS8Dy06V6pT',
#   '4ETSs924pXMzjIeD6E9b4u',
#   '4q3ewBCX7sLwd24euuV69X',
#   '181bsRPaVXVlUKXrxwZfHK',
#   '4q3ewBCX7sLwd24euuV69X',
#   '790FomKkXshlbRYZFtlgla',
#   '0vRvGUQVUjytro0xpb26bs',
#   '4GNC7GD6oZMSxPGyXy4MNB',
#   '5cj0lLjcoR7YOSnhnX0Po5',
#   '1Xyo4u8uXC1ZmMpatF05PJ',
#   '246dkjvS1zLTtiykXe5h60',
#   '6M2wZ9GZgrQXHCFfjv46we',
#   '699OTQXzgjhIYAHMy9RyPD',
#   '2wY79sveU1sp5g7SokKOiI',
#   '2LIk90788K0zvyj2JJVwkJ',
#   '28gNT5KBp7IjEOQoevXf9N',
#   '6KImCVD70vtIoJWnq6nGn3',
#   '04gDigrS5kc9YWfZHwBETP',
#   '1RyvyyTE3xzB2ZywiAwp0i',
# ...

# %%
df = pd.DataFrame(artist_data)
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#                 artist_id artist_name  \
# 0  1Xyo4u8uXC1ZmMpatF05PJ  The Weeknd
# 1  3TVXtAsR1Inumwj472S9r4       Drake
# 2  0H39MdGGX6dbnnQPt6NQkZ   SAINt JHN
# 3  6M2wZ9GZgrQXHCFfjv46we    Dua Lipa
# 4  6bmlMHgSheBauioMgKv2tn       Powfu
#
#                                         artist_genre  artist_popularity
# 0       canadian contemporary r&b, canadian pop, pop                 98
# 1  canadian hip hop, canadian pop, hip hop, pop r...                 99
# 2                    melodic rap, pop rap, rap, trap                 88
# 3                             dance pop, pop, uk pop                 96
# 4                                                                    87

# %%
df.to_csv('artist_data.csv', index = False)

# %%
engine = create_engine('mysql://USERNAME:PASSWORD@HOST/DATABASE')

# %%
df.to_sql('artists',engine, if_exists='replace')

# %% [markdown]
# # SQL

# %%
# %load_ext sql

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE
# Out:
# 'Connected: admin@sql_project'

# %%
# %%sql
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%pop%'
# ORDER BY artist_popularity DESC;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 24 rows affected.
# [(1, '3TVXtAsR1Inumwj472S9r4', 'Drake', 'canadian hip hop, canadian pop, hip hop, pop rap, rap, toronto rap', 99),
#  (0, '1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd', 'canadian contemporary r&b, canadian pop, pop', 98),
#  (3, '6M2wZ9GZgrQXHCFfjv46we', 'Dua Lipa', 'dance pop, pop, uk pop', 96),
#  (32, '6qqNVTkY8uBg9cP3Jd7DAH', 'Billie Eilish', 'electropop, pop', 96),
#  (11, '1uNFoZAHBGtllmzznpCI3s', 'Justin Bieber', 'canadian pop, pop, post-teen pop', 95),
#  (31, '1RyvyyTE3xzB2ZywiAwp0i', 'Future', 'atl hip hop, pop rap, rap, southern hip hop, trap', 92),
#  (8, '5cj0lLjcoR7YOSnhnX0Po5', 'Doja Cat', 'la indie, pop', 91),
#  (20, '4GNC7GD6oZMSxPGyXy4MNB', 'Lewis Capaldi', 'pop, uk pop', 90),
#  (26, '2wY79sveU1sp5g7SokKOiI', 'Sam Smith', 'pop, post-teen pop, uk pop', 90),
#  (29, '6KImCVD70vtIoJWnq6nGn3', 'Harry Styles', 'pop, post-teen pop', 90),
# ...

# %% [markdown]
# After running this query I realized it would be difficult to run the queries I wanted to because there was a list of genres including sub genres. I knew I had to change all of them to representative of the overarching genres only.

# %%
# %%sql
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%latin%';
#
# UPDATE artists
# SET artist_genre = 'latin'
# WHERE artist_genre LIKE '%latin%';
#
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%edm%';
#
# UPDATE artists
# SET artist_genre = 'edm'
# WHERE artist_genre LIKE '%edm%';
#
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%hip hop%' OR artist_genre LIKE '%rap%';
#
# UPDATE artists
# SET artist_genre = 'rap'
# WHERE artist_genre LIKE '%hip hop%' OR artist_genre LIKE '%rap%';
#
# SELECT *
# FROM artists
# WHERE artist_name = 'Trevor Daniel';
#
# UPDATE artists
# SET artist_genre = 'pop'
# WHERE artist_name = 'Trevor Daniel';
#
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%rock%';
#
# UPDATE artists
# SET artist_genre = 'rock'
# WHERE artist_genre LIKE '%rock%';
#
#
# UPDATE artists
# SET artist_genre = 'rap'
# WHERE artist_name = 'DripReport';
#
# SELECT *
# FROM artists
# WHERE artist_name = 'DripReport';
#
# SELECT *
# FROM artists
# WHERE artist_name = 'Surf Mesa';
#
# UPDATE artists
# SET artist_genre = 'edm'
# WHERE artist_name = 'Surf Mesa';
#
# SELECT *
# FROM artists
# WHERE artist_genre LIKE '%pop%';
#
# UPDATE artists
# SET artist_genre = 'pop'
# WHERE artist_genre LIKE '%pop%' OR artist_name = 'powfu';
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 5 rows affected.
# 5 rows affected.
# 1 rows affected.
# 1 rows affected.
# 13 rows affected.
# 13 rows affected.
# 1 rows affected.
# 1 rows affected.
# 2 rows affected.
# 2 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 15 rows affected.
# 16 rows affected.
# []

# %% [markdown]
# After runing these SQL queries I edited all of the artist genres to be representative of that artists overarching genre

# %%
# %%sql
# SELECT *
# FROM artists
# ORDER BY artist_genre;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 38 rows affected.
# [('4ofCBoyEiGSePFAG500xev', 'Regard', 'edm', 79),
#  ('1lmU3giNF3CSbkVSQmLpHQ', 'Surf Mesa', 'edm', 78),
#  ('28gNT5KBp7IjEOQoevXf9N', 'Camilo', 'latin', 88),
#  ('1vyhD5VmyZ7KMfW5gqLgo5', 'J Balvin', 'latin', 97),
#  ('1mcTU81TzQhprhouKaTkpq', 'Rauw Alejandro', 'latin', 91),
#  ('790FomKkXshlbRYZFtlgla', 'KAROL G', 'latin', 88),
#  ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny', 'latin', 100),
#  ('4ETSs924pXMzjIeD6E9b4u', 'Surfaces', 'pop', 85),
#  ('6qqNVTkY8uBg9cP3Jd7DAH', 'Billie Eilish', 'pop', 96),
#  ('6KImCVD70vtIoJWnq6nGn3', 'Harry Styles', 'pop', 90),
#  ('2wY79sveU1sp5g7SokKOiI', 'Sam Smith', 'pop', 90),
#  ('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd', 'pop', 98),
#  ('4GNC7GD6oZMSxPGyXy4MNB', 'Lewis Capaldi', 'pop', 90),
#  ('7n2wHs1TKAczGzO7Dd2rGr', 'Shawn Mendes', 'pop', 90),
#  ('7uaIm6Pw7xplS8Dy06V6pT', 'Trevor Daniel', 'pop', 85),
# ...

# %% [markdown]
# I noticed that there is some data redundency in this additionally the foreign key for the genres is missing. Instead of the overarching genre I need to replace it with the genre ID.

# %%
# %%sql
# ALTER TABLE artists
# ADD genre_id INT(11) NOT NULL;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 0 rows affected.
# []

# %% [markdown]
# I added a genre_id column to the artists table

# %%
# %%sql
#
# SELECT genre_id, genre_name
# FROM genres;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 10 rows affected.
# [(1, 'pop'),
#  (2, 'rock'),
#  (3, 'rap'),
#  (4, 'indie'),
#  (5, 'edm'),
#  (6, 'country'),
#  (7, 'r&b'),
#  (8, 'latin'),
#  (9, 'classical'),
#  (10, 'jazz')]

# %% [markdown]
# This displays all the genres with their id next to it so I can update the genre_id column in the artists table

# %%
# %%sql
# UPDATE artists
# SET genre_id = 1
# WHERE artist_genre = 'pop';
#
# UPDATE artists
# SET genre_id = 2
# WHERE artist_genre = 'rock';
#
# UPDATE artists
# SET genre_id = 3
# WHERE artist_genre = 'rap';
#
# UPDATE artists
# SET genre_id = 4
# WHERE artist_genre = 'indie';
#
# UPDATE artists
# SET genre_id = 5
# WHERE artist_genre = 'edm';
#
# UPDATE artists
# SET genre_id = 6
# WHERE artist_genre = 'country';
#
# UPDATE artists
# SET genre_id = 7
# WHERE artist_genre = 'r&b';
#
# UPDATE artists
# SET genre_id = 8
# WHERE artist_genre = 'latin';
#
# UPDATE artists
# SET genre_id = 9
# WHERE artist_genre = 'classical';
#
# UPDATE artists
# SET genre_id = 10
# WHERE artist_genre = 'jazz';
#
# ALTER TABLE artists
# DROP artist_genre;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 16 rows affected.
# 2 rows affected.
# 13 rows affected.
# 0 rows affected.
# 2 rows affected.
# 0 rows affected.
# 0 rows affected.
# 5 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM artists;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 38 rows affected.
# [('1Xyo4u8uXC1ZmMpatF05PJ', 'The Weeknd', 98, 1),
#  ('3TVXtAsR1Inumwj472S9r4', 'Drake', 99, 3),
#  ('0H39MdGGX6dbnnQPt6NQkZ', 'SAINt JHN', 88, 3),
#  ('6M2wZ9GZgrQXHCFfjv46we', 'Dua Lipa', 96, 1),
#  ('6bmlMHgSheBauioMgKv2tn', 'Powfu', 87, 1),
#  ('2NjfBq1NflQcKSeiDooVjY', 'Tones And I', 88, 1),
#  ('757aE44tKEUQEqRuT6GnEB', 'Roddy Ricch', 94, 3),
#  ('5zctI4wO9XSKS8XwcnqEHk', 'Lil Mosey', 88, 3),
#  ('5cj0lLjcoR7YOSnhnX0Po5', 'Doja Cat', 91, 1),
#  ('4r63FhuTkUYltbVAg5TQnk', 'DaBaby', 94, 3),
#  ('1uNFoZAHBGtllmzznpCI3s', 'Justin Bieber', 95, 1),
#  ('0Cp8WN4V8Tu4QJQwCN5Md4', 'BENEE', 84, 1),
#  ('7uaIm6Pw7xplS8Dy06V6pT', 'Trevor Daniel', 85, 1),
#  ('4ETSs924pXMzjIeD6E9b4u', 'Surfaces', 85, 1),
#  ('4q3ewBCX7sLwd24euuV69X', 'Bad Bunny', 100, 8),
#  ('181bsRPaVXVlUKXrxwZfHK', 'Megan Thee Stallion', 86, 3),
#  ('790FomKkXshlbRYZFtlgla', 'KAROL G', 88, 8),
# ...

# %% [markdown]
# I updated the genre_id column in the artist table and then dropped the artist_genre column because that information is already stored in the genres table

# %% [markdown]
# ## SQL #1
#
# Question: Create a table that displays who the top performing artists are.
#
# Business Justification: By seeing the artists who have the most songs in the top 50 chart, we can see which artist creates the most top tracks. We will pursue that artist to try to create deals and try to tailor some of the Apple Music marketing with the use of those better performing artists.
#
# SQL features: Common Table Expression, Join, Group by

# %%
# %%sql
# #CTE to see which artists have the most top songs
# WITH artist_top_song_count AS (
#     SELECT artist_name, track_name
#     FROM top_50_songs
#     JOIN artists
#         ON artists.artist_id = top_50_songs.artist_id
# )
#
# SELECT artist_name, COUNT(*) AS num_top_songs
# FROM artist_top_song_count
# GROUP BY artist_name
# ORDER BY num_top_songs DESC;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 38 rows affected.
# [('Bad Bunny', 5),
#  ('Dua Lipa', 3),
#  ('The Weeknd', 2),
#  ('Doja Cat', 2),
#  ('DaBaby', 2),
#  ('Lewis Capaldi', 2),
#  ('Billie Eilish', 2),
#  ('J Balvin', 2),
#  ('Tones And I', 1),
#  ('Surfaces', 1),
#  ('Sam Smith', 1),
#  ('Surf Mesa', 1),
#  ('MEDUZA', 1),
#  ('Roddy Ricch', 1),
#  ('Jack Harlow', 1),
#  ('Shawn Mendes', 1),
#  ('Lil Mosey', 1),
#  ('Megan Thee Stallion', 1),
#  ('Camilo', 1),
#  ('DripReport', 1),
#  ('KAROL G', 1),
#  ('Harry Styles', 1),
#  ('Eminem', 1),
#  ('Drake', 1),
#  ('Arizona Zervas', 1),
#  ('Maroon 5', 1),
#  ('JP Saxe', 1),
#  ('SAINt JHN', 1),
#  ('Justin Bieber', 1),
#  ('Future', 1),
#  ('Rauw Alejandro', 1),
#  ('BENEE', 1),
#  ('Post Malone', 1),
#  ('Travis Scott', 1),
#  ('Powfu', 1),
#  ('Trevor Daniel', 1),
#  ('Playboi Carti', 1),
#  ('Twenty One Pilots', 1)]

# %% [markdown]
# ## SQL #1
#
# Reccomendation:
#
# Based on these results we see that the artist that performs the most top songs is Bad Bunny. As for my reccomendation, I believe that Apple Music should strike some sort of deal with Bad Bunny, for example, have him release his music exclusively on Apple Music for a week before releasing on other platforms. Additionally, if Bad Bunny would not agree to that, Dua Lipa,  who follows Bad Bunny's 5 top songs with 3 top songs, could be another target for a similar promotional plan.

# %% [markdown]
# ## SQL #2
#
# Question: Create a classification for popular artists, who are artists that have a popularity rating greater than that of industry standard.
#
# Business Justification: We can filter out the artists that have a popularity rating lower than that of the average for the specific genre. Then by seeing which artists have the highest popularity rating we can see which artists have a the majority of people listening to their music. This will indicate which artists are good to pursue in partnerships regardless if they do not have many songs in the current top 50 chart.
#
# SQL Features: Case, Common Table Expression, Join, Window

# %%
# %%sql
# WITH artist_genre_popularity AS (
#     SELECT
#         artist_name,
#         genres.genre_name,
#         artist_popularity,
#         AVG(artist_popularity) OVER(PARTITION BY artists.genre_id) AS avg_artist_popularity_per_genre,
#
#             CASE
#                 WHEN artists.artist_popularity < 90 THEN 'Mildly Popular'
#                 WHEN artists.artist_popularity BETWEEN 90 AND 95 THEN 'More Popular'
#                 ELSE 'Extremely Popular'
#             END AS 'popularity_level'
#
#     FROM artists
#     JOIN genres
#         ON artists.genre_id = genres.genre_id
# )
#
# SELECT *
# FROM artist_genre_popularity
# WHERE artist_popularity > avg_artist_popularity_per_genre
# ORDER BY artist_popularity DESC;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 20 rows affected.
# [('Bad Bunny', 'latin', 100, Decimal('92.8000'), 'Extremely Popular'),
#  ('Drake', 'rap', 99, Decimal('89.9286'), 'Extremely Popular'),
#  ('Travis Scott', 'rap', 98, Decimal('89.9286'), 'Extremely Popular'),
#  ('The Weeknd', 'pop', 98, Decimal('89.1875'), 'Extremely Popular'),
#  ('J Balvin', 'latin', 97, Decimal('92.8000'), 'Extremely Popular'),
#  ('Dua Lipa', 'pop', 96, Decimal('89.1875'), 'Extremely Popular'),
#  ('Post Malone', 'rap', 96, Decimal('89.9286'), 'Extremely Popular'),
#  ('Billie Eilish', 'pop', 96, Decimal('89.1875'), 'Extremely Popular'),
#  ('Justin Bieber', 'pop', 95, Decimal('89.1875'), 'More Popular'),
#  ('Eminem', 'rap', 95, Decimal('89.9286'), 'More Popular'),
#  ('Roddy Ricch', 'rap', 94, Decimal('89.9286'), 'More Popular'),
#  ('DaBaby', 'rap', 94, Decimal('89.9286'), 'More Popular'),
#  ('Future', 'rap', 92, Decimal('89.9286'), 'More Popular'),
# ...

# %% [markdown]
# ## SQL #2
#
# Reccomendation: From this table we see once again that Bad Bunny has a high popularity rating that is higher than the genre average.
#
# If looking at just the popularity rating, Bad Bunny would be the clear cut pick for a branding deal.
#
# However, artists like Travis Scott, Drake, and The Weeknd all are categorized as extremely popular and have a popularity rating that is about 9-10 points higher than their respective genre average. Therefore, these would be the best artists for Apple Music to pursue to get deals with or create playlist that are more tailored to those listening to these artists. Even though from the past query we saw that they only had 1 song in the top charts

# %% [markdown]
# ## SQL #3
#
# Question: Create a query that displays the the top genres and the percentage of each age group that listens to that genre.
#
# Business Justification: By showing the most popular genres and their respective age groups, we can choose which age group to market towards and form a target market for Apple Music using that. Additionally, marketing can be ramped up for specific genres in specific age groups while other genres and age groups not so much.
#
# SQL features: View, Join, Group By

# %%
# %%sql
# CREATE OR REPLACE VIEW top_songs_by_artists_with_genre AS
#     SELECT artists.artist_name, top_50_songs.track_name, genres.genre_id, genres.genre_name, genres.age_16_19,
#         genres.age_20_24, genres.age_25_34, genres.age_35_44, genres.age_45_54, genres.age_55_64, genres.age_65_plus
#     FROM top_50_songs
#     JOIN artists
#         ON top_50_songs.artist_id = artists.artist_id
#     JOIN genres
#         ON artists.genre_id = genres.genre_id;
#
# SELECT
#     genre_id, genre_name, age_16_19,
#     age_20_24, age_25_34, age_35_44,
#     age_45_54, age_55_64, age_65_plus,
#     COUNT(*) AS num_of_top_songs_in_genre
# FROM top_songs_by_artists_with_genre
# GROUP BY genre_id
# ORDER BY COUNT(*) DESC;
# Out:
#  * mysql://admin:***@lmu-sql.crkxqhoxro46.us-east-2.rds.amazonaws.com/sql_project
# 0 rows affected.
# 5 rows affected.
# [(1, 'pop', 52, 54, 56, 46, 42, 25, 19, 21),
#  (3, 'rap', 48, 54, 42, 33, 15, 5, 1, 14),
#  (8, 'latin', 30, 35, 36, 34, 21, 13, 5, 10),
#  (5, 'edm', 20, 33, 15, 21, 9, 5, 1, 3),
#  (2, 'rock', 26, 36, 44, 46, 62, 60, 48, 2)]

# %% [markdown]
# ## SQL #3
#
# Reccomendation:
#
# We see by far that pop has the most songs in the top 50 charts. Therefore if resources were to be given towards marketing the most popular genre it would be pop. Additionally, the age groups demonstrate that more than half of those from age 16-34 listen to pop music. Therefore, marketing should be done towards Millenials and Gen Z.

# %% [markdown]
# # Conclusion
#
# Job Posting: Content Data Scientist, Apple Media Products Data Science
#
# Data: Spotify API
#
# Main Insight: Target millenials and Gen Z
